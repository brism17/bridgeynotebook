// %% [markdown]
// An h1 header
// ============
//
// Paragraphs are separated by a blank line.
//
// 2nd paragraph. *Italic*, **bold**, and `monospace`. Itemized lists
// look like:
//
//   * this one
//   * that one
//   * the other one
//
// Note that --- not considering the asterisk --- the actual text
// content starts at 4-columns in.
//
// > Block quotes are
// > written like so.
// >
// > They can span multiple paragraphs,
// > if you like.
//
// Use 3 dashes for an em-dash. Use 2 dashes for ranges (ex., "it's all
// in chapters 12--14"). Three dots ... will be converted to an ellipsis.
// Unicode is supported. ☺
//
// Here is an example of `inline code`
//
//
//
// An h2 header
// ------------
//
// Here's a numbered list:
//
//  1. first item
//  2. second item
//  3. third item
//
// Note again how the actual text starts at 4 columns in (4 characters
// from the left side). Here's a code sample:
//
//     # Let me re-iterate ...
//     for i in 1 .. 10 { do-something(i) }
//
// As you probably guessed, indented 4 spaces. By the way, instead of
// indenting the block, you can use delimited blocks, if you like:
//
// ~~~
// define foobar() {
//     print "Welcome to flavor country!";
// }
// ~~~
//
// (which makes copying & pasting easier). You can optionally mark the
// delimited block for Pandoc to syntax highlight it:
//
// ~~~python
// import time
// # Quick, count to ten!  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nulla vel nulla pretium, suscipit purus ac, lobortis ante. Integer in nulla viverra, consectetur leo at, dapibus turpis. In malesuada malesuada porttitor. Vivamus fermentum justo sit amet ligula tincidunt, vel placerat metus maximus. Donec ut aliquet mauris. Suspendisse potenti. Nullam sed risus nec lectus dignissim vestibulum. Vestibulum urna eros, malesuada eget efficitur at, lobortis sed tortor. Aenean luctus eleifend volutpat. Nullam nec purus quis tellus commodo tincidunt. Donec et faucibus mauris. Quisque fringilla lorem vitae felis mollis tincidunt. Mauris semper mi sed lorem lacinia, in iaculis sem dictum. Nulla vulputate, risus in pretium faucibus, leo magna fermentum ipsum, ac venenatis neque sem vitae nibh. Pellentesque tincidunt orci sed aliquam rutrum.
//
// Vivamus egestas augue et ex porta, eget luctus orci lobortis. Donec sem enim, viverra at nibh aliquet, euismod sagittis sem. Vestibulum ac diam nec justo maximus gravida. Nullam tincidunt justo non lacus eleifend, non dapibus velit viverra. Maecenas non orci enim. Ut convallis eu neque id maximus. Duis tincidunt feugiat ligula eu aliquam. Fusce egestas magna sed orci suscipit ultrices. Aliquam scelerisque, diam non viverra gravida, ligula nunc tincidunt massa, ut egestas velit nibh sed dui. Ut tempus et ligula id viverra.
//
// Etiam quis sapien vitae odio fermentum rhoncus. Suspendisse potenti. Maecenas eros mi, molestie et massa sit amet, consequat consequat libero. Nullam commodo, est consectetur luctus ullamcorper, nunc mi iaculis ex, egestas condimentum mi ligula vel est. Integer feugiat magna at eros eleifend, nec auctor justo tristique. Suspendisse aliquet ullamcorper dui, eget venenatis leo mattis sit amet. Integer turpis libero, pretium a ornare non, gravida ut diam. Sed eget aliquet lacus. Aenean rhoncus fermentum nisi, in ullamcorper ante hendrerit quis. Praesent aliquam malesuada diam nec vulputate. Nam volutpat viverra dui sit amet mattis. Aenean id arcu a massa auctor lobortis at quis enim.
//
// Vivamus vitae tempus magna, eu condimentum metus. Pellentesque in sagittis augue, in maximus magna. Curabitur ultrices ac massa eget consequat. Donec vel elit est. Praesent ullamcorper felis sit amet felis posuere vehicula. Suspendisse viverra vulputate quam eu facilisis. Quisque a leo rutrum orci semper imperdiet. Praesent mollis euismod lectus eu blandit. Suspendisse non mi velit. Aenean scelerisque, sem vel auctor pretium, dui quam convallis nisi, sit amet accumsan augue sem at est. Suspendisse laoreet neque vitae sapien facilisis, et semper urna volutpat. Phasellus euismod magna id magna tristique scelerisque. Vestibulum porta commodo odio, quis accumsan risus pellentesque eu. Nunc arcu ligula, molestie id tristique vel, placerat ac eros. Ut a sollicitudin metus. Nam luctus dignissim ligula eget commodo.
//
// Integer semper magna lorem, ac viverra tortor viverra ut. Mauris viverra urna venenatis est mollis, at varius justo sollicitudin. Integer tincidunt imperdiet metus nec accumsan. Nulla lobortis fermentum porta. Aenean id quam nibh. Nullam a lorem laoreet, pellentesque dui in, convallis ligula. Proin eu dui ultricies, condimentum neque dapibus, tempor est. Praesent vel risus vitae nulla placerat finibus gravida in turpis. Aenean velit quam, blandit sit amet arcu eu, pulvinar gravida erat. Proin vestibulum condimentum nisi eu rutrum. Etiam libero nisi, commodo vel rhoncus non, porttitor a ante. Praesent mauris nibh, ullamcorper non lacus vel, lobortis molestie enim. Nunc vel nisl eget orci tempus faucibus auctor tempus orci. Maecenas cursus, quam a malesuada blandit, lectus ex ultrices magna, pulvinar pellentesque dui nulla a nisi. Nunc scelerisque bibendum est at facilisis. Nam augue diam, finibus quis erat ac, ultricies congue nulla.
// for i in range(10):
//     # (but not *too* quick)
//     time.sleep(0.5)
//     print(i)
// ~~~
//
//
//
// ### An h3 header ###
//
// Now a nested list:
//
//  1. First, get these ingredients:
//
//       * carrots
//       * celery
//       * lentils
//
//  2. Boil some water.
//
//  3. Dump everything in the pot and follow
//     this algorithm:
//
//         find wooden spoon
//         uncover pot
//         stir
//         cover pot
//         balance wooden spoon precariously on pot handle
//         wait 10 minutes
//         goto first step (or shut off burner when done)
//
//     Do not bump wooden spoon or it will fall.
//
// Notice again how text always lines up on 4-space indents (including
// that last line which continues item 3 above).
//
// Here's a link to [a website](http://foo.bar), to a [local
// doc](local-doc.html), and to a [section heading in the current
// doc](#an-h2-header). Here's a footnote [^1].
//
// [^1]: Some footnote text.
//
// Tables can look like this:
//
// Name           Size  Material      Color
// ------------- -----  ------------  ------------
// All Business      9  leather       brown
// Roundabout       10  hemp canvas   natural
// Cinderella       11  glass         transparent
//
// Table: Shoes sizes, materials, and colors.
//
// (The above is the caption for the table.) Pandoc also supports
// multi-line tables:
//
// --------  -----------------------
// Keyword   Text
// --------  -----------------------
// red       Sunsets, apples, and
//           other red or reddish
//           things.
//
// green     Leaves, grass, frogs
//           and other things it's
//           not easy being.
// --------  -----------------------
//
// A horizontal rule follows.
//
// ***
//
// Here's a definition list:
//
// apples
//   : Good for making applesauce.
//
// oranges
//   : Citrus!
//
// tomatoes
//   : There's no "e" in tomatoe.
//
// Again, text is indented 4 spaces. (Put a blank line between each
// term and  its definition to spread things out more.)
//
// Here's a "line block" (note how whitespace is honored):
//
// | Line one
// |   Line too
// | Line tree
//
// and images can be specified like so:
//
// ![example image](example-image.jpg "An exemplary image")
//
// Inline math equation: $\omega = d\phi / dt$. Display
// math should get its own line like so:
//
// $$I = \int \rho R^{2} dV$$
//
// And note that you can backslash-escape any punctuation characters
// which you wish to be displayed literally, ex.: \`foo\`, \*bar\*, etc.
