// %%
%azure.connect "/subscriptions/677fc922-91d0-4bf6-9b06-4274d319a0fa/resourceGroups/xiou/providers/Microsoft.Quantum/Workspaces/xiou-notebooks-demo" location="eastus2euap"
// Out:
// Authenticated using Microsoft.Azure.Quantum.Authentication.TokenFileCredential
//
//
// Connected to Azure Quantum workspace xiou-notebooks-demo in location eastus2euap.
// Target ID      Current Availability Average Queue Time (Seconds)
// -------------- --------- --
// ionq.qpu       Available 18
// ionq.simulator Available 5

// %%
%azure.jobs
// Out:
// Showing only the first 30 jobs:
// Job Name                         Job ID                                                                                                                                                                                                                                                                                                                                               Job Status Target                                         Creation Time              Begin Execution Time       End Execution Time
// ...
